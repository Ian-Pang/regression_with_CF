# %%
import os
import numpy as np
import torch
import torch.nn.functional as F
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
plt.rcParams['figure.dpi'] = 150
from nflows import transforms, distributions, flows
import torch.optim as optim
from nflows.utils import torchutils
from data import get_dataloader
import h5py
torch.set_default_dtype(torch.float64)

particle = 'piplus'

preproc = 'log10'

# %%
# folder containing the GEANT data used to train/validate Caloflow
trg_data_folder = '/home/yp325/regression_project/regression_with_CF/hdf5-helper'

discrete_folder = '/home/yp325/regression_project/data_discrete_100k'

# %%
device = torch.device('cuda:0')

# %%
# utilities, some are no longer used with log10 preproc
ALPHA = 1e-6
def logit(x):
    """ returns logit of input """
    return torch.log(x / (1.0 - x))

def logit_trafo(x):
    """ implements logit trafo of MAF paper https://arxiv.org/pdf/1705.07057.pdf """
    local_x = ALPHA + (1. - 2.*ALPHA) * x
    return logit(local_x)

def inverse_logit(x, clamp_low=0., clamp_high=1.):
    """ inverts logit_trafo(), clips result if needed """
    return ((torch.sigmoid(x) - ALPHA) / (1. - 2.*ALPHA)).clamp_(clamp_low, clamp_high)

def trafo_to_unit_space(energy_array):
    """ transforms energy array to be in [0, 1] """
    num_dim = len(energy_array[0])-2
    ret = [(torch.sum(energy_array[:, :-1], dim=1)/energy_array[:, -1]).unsqueeze(1)]
    for n in range(num_dim):
        ret.append((energy_array[:, n]/energy_array[:, n:-1].sum(dim=1)).unsqueeze(1))
    return torch.cat(ret, 1).clamp_(0., 1.)

def trafo_to_energy_space(unit_array, etot_array):
    """ transforms unit array to be back in energy space """
    assert len(unit_array) == len(etot_array)
    num_dim = len(unit_array[0])
    unit_array = torch.cat((unit_array, torch.ones(size=(len(unit_array), 1)).to(unit_array.device)), 1)
    ret = [torch.zeros_like(etot_array)]
    ehat_array = unit_array[:, 0] * etot_array
    for n in range(num_dim):
        ret.append(unit_array[:, n+1]*(ehat_array-torch.cat(ret).view(
            n+1, -1).transpose(0, 1).sum(dim=1)))
    ret.append(etot_array)
    return torch.cat(ret).view(num_dim+2, -1)[1:].transpose(0, 1)

class RandomPermutationLayer(transforms.Permutation):
    """ Permutes elements with random, but fixed permutation. Keeps pixel inside layer. """
    def __init__(self, features, dim=1):
        """ features: list of dimensionalities to be permuted"""
        assert isinstance(features, list), ("Input must be a list of integers!")
        permutations = []
        for index, features_entry in enumerate(features):
            current_perm = np.random.permutation(features_entry)
            if index == 0:
                permutations.extend(current_perm)
            else:
                permutations.extend(current_perm + np.cumsum(features)[index-1])
        super().__init__(torch.tensor(permutations), dim)

class InversionLayer(transforms.Permutation):
    """ Inverts the order of the elements in each layer.  Keeps pixel inside layer. """
    def __init__(self, features, dim=1):
        """ features: list of dimensionalities to be inverted"""
        assert isinstance(features, list), ("Input must be a list of integers!")
        permutations = []
        for index, features_entry in enumerate(features):
            current_perm = np.arange(features_entry)[::-1]
            if index == 0:
                permutations.extend(current_perm)
            else:
                permutations.extend(current_perm + np.cumsum(features)[index-1])
        super().__init__(torch.tensor(permutations), dim)

def add_noise(input_tensor,noiseamount=1e-8):
    noise = np.random.rand(*input_tensor.shape)*noiseamount
    return input_tensor+noise

def add_fake_noise(input_tensor,noiseamount=1e-8):
    noise = noiseamount/2
    return input_tensor+noise

# %% [markdown]
# # Define and load layer energy model

# %%
class RegressionLayerNet(nn.Module):
    def __init__(self):
        super(RegressionLayerNet, self).__init__()
        self.fc1 = nn.Linear(6, 256)  
        self.fc2 = nn.Linear(256, 256)
        self.fc3 = nn.Linear(256, 256)
        self.fc4 = nn.Linear(256, 1)  

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %% [markdown]
# ## Train layer energy model

# %%
kwargs = {'num_workers': 2, 'pin_memory': True} if device.type is 'cuda' else {}
batch_size = 200
num_epochs = 200
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_475586/3665156468.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   kwargs = {'num_workers': 2, 'pin_memory': True} if device.type is 'cuda' else {}

# %%
train_dataloader, val_dataloader = get_dataloader('piplus',
                                                           trg_data_folder,
                                                           full=False,
                                                           apply_logit=False,
                                                           device=device,
                                                           batch_size=batch_size,
                                                           with_noise=False,
                                                           normed=False,
                                                           normed_layer=False) #change dataset as appropriate

# %%
model_dir = "MSE_uniform_models_large/" #change as appropriate

# %%
for instance in range(10):
    # Create an instance of the regression model
    model = RegressionLayerNet().to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    lr_schedule = torch.optim.lr_scheduler.MultiStepLR(optimizer,
                                                        milestones=[15, 50, 100, 150],
                                                        gamma=0.5,
                                                        verbose=True)
    best_model_path = model_dir+'best_model_uniform_'+str(instance)+'.pth' #change as appropriate
    best_val_loss = float('inf')
    for epoch in range(num_epochs):
        for i, batch in enumerate(train_dataloader):
            model.train()
            energy = batch['energy']
            E0 = batch['layer_0_E']
            E1 = batch['layer_1_E']
            E2 = batch['layer_2_E']
            E3 = batch['layer_3_E']
            E4 = batch['layer_4_E']
            E5 = batch['layer_5_E']

            y = torch.log10(energy*10.).to(device)
            x = torch.cat((E0.unsqueeze(1),
                        E1.unsqueeze(1),
                        E2.unsqueeze(1),
                        E3.unsqueeze(1),
                        E4.unsqueeze(1),
                        E5.unsqueeze(1)), 1).to(device)

            outputs = model(x)
            loss = criterion(outputs, y)

            # Backpropagation and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        with torch.no_grad():
            model.eval()
            val_losses = []
            for i, batch in enumerate(val_dataloader):
                energy = batch['energy']
                E0 = batch['layer_0_E']
                E1 = batch['layer_1_E']
                E2 = batch['layer_2_E']
                E3 = batch['layer_3_E']
                E4 = batch['layer_4_E']
                E5 = batch['layer_5_E']

                y_val = torch.log10(energy*10.).to(device)
                x_val = torch.cat((E0.unsqueeze(1),
                            E1.unsqueeze(1),
                            E2.unsqueeze(1),
                            E3.unsqueeze(1),
                            E4.unsqueeze(1),
                            E5.unsqueeze(1)), 1).to(device)

                val_outputs = model(x_val)
                val_loss = criterion(val_outputs, y_val)
                val_losses.append(val_loss.item())
            overall_val_loss = np.array(val_losses)

            val_loss_mean = overall_val_loss.mean(0)
            val_loss_std = np.sqrt(overall_val_loss.var(0))

        lr_schedule.step()
        output = 'Evaluate (epoch {}) -- '.format(epoch+1) +\
                    'MSE loss = {:.6f} +/- {:.6f}'
        if val_loss_mean < best_val_loss:
            best_val_loss = val_loss_mean
            # Save the best model checkpoint
            torch.save(model.state_dict(), best_model_path)
        print(output.format(val_loss_mean, val_loss_std))
# Out:
# Adjusting learning rate of group 0 to 1.0000e-04.
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 1) -- MSE loss = 0.014668 +/- 0.004336
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 2) -- MSE loss = 0.006073 +/- 0.001972
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 171) -- MSE loss = 0.002950 +/- 0.000810
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 172) -- MSE loss = 0.002950 +/- 0.000810
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 173) -- MSE loss = 0.002938 +/- 0.000808
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 174) -- MSE loss = 0.002940 +/- 0.000807
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 175) -- MSE loss = 0.002940 +/- 0.000807
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 176) -- MSE loss = 0.002950 +/- 0.000808
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 177) -- MSE loss = 0.002948 +/- 0.000812
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 178) -- MSE loss = 0.002951 +/- 0.000816
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 179) -- MSE loss = 0.002941 +/- 0.000811
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 180) -- MSE loss = 0.002942 +/- 0.000809
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 181) -- MSE loss = 0.002984 +/- 0.000812
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 182) -- MSE loss = 0.002949 +/- 0.000808
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 183) -- MSE loss = 0.002947 +/- 0.000806
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 184) -- MSE loss = 0.002946 +/- 0.000811
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 185) -- MSE loss = 0.002939 +/- 0.000809
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 186) -- MSE loss = 0.002938 +/- 0.000808
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 187) -- MSE loss = 0.002939 +/- 0.000806
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 188) -- MSE loss = 0.002951 +/- 0.000810
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 189) -- MSE loss = 0.002940 +/- 0.000809
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 190) -- MSE loss = 0.002953 +/- 0.000810
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 191) -- MSE loss = 0.002975 +/- 0.000810
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 192) -- MSE loss = 0.002938 +/- 0.000809
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 193) -- MSE loss = 0.002938 +/- 0.000809
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 194) -- MSE loss = 0.002947 +/- 0.000810
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 195) -- MSE loss = 0.002955 +/- 0.000805
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 196) -- MSE loss = 0.002942 +/- 0.000811
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 197) -- MSE loss = 0.002945 +/- 0.000807
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 198) -- MSE loss = 0.002951 +/- 0.000804
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 199) -- MSE loss = 0.002942 +/- 0.000806
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 200) -- MSE loss = 0.002957 +/- 0.000806
# Adjusting learning rate of group 0 to 1.0000e-04.
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 1) -- MSE loss = 0.012872 +/- 0.003586
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 2) -- MSE loss = 0.005773 +/- 0.001820
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 3) -- MSE loss = 0.004383 +/- 0.001461
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 4) -- MSE loss = 0.003957 +/- 0.001318
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 5) -- MSE loss = 0.003565 +/- 0.001221
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 6) -- MSE loss = 0.003506 +/- 0.001145
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 7) -- MSE loss = 0.003331 +/- 0.001094
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 8) -- MSE loss = 0.003255 +/- 0.001060
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 9) -- MSE loss = 0.003190 +/- 0.001044
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 10) -- MSE loss = 0.003205 +/- 0.001029
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 11) -- MSE loss = 0.003157 +/- 0.001019
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 12) -- MSE loss = 0.003224 +/- 0.001025
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 13) -- MSE loss = 0.003157 +/- 0.000996
# Adjusting learning rate of group 0 to 1.0000e-04.
# Evaluate (epoch 14) -- MSE loss = 0.003081 +/- 0.000983
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 15) -- MSE loss = 0.003088 +/- 0.000981
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 16) -- MSE loss = 0.003057 +/- 0.000961
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 17) -- MSE loss = 0.003198 +/- 0.000977
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 18) -- MSE loss = 0.003111 +/- 0.000963
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 19) -- MSE loss = 0.003034 +/- 0.000954
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 20) -- MSE loss = 0.003105 +/- 0.000950
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 21) -- MSE loss = 0.003037 +/- 0.000951
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 22) -- MSE loss = 0.003026 +/- 0.000942
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 23) -- MSE loss = 0.003037 +/- 0.000945
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 24) -- MSE loss = 0.003029 +/- 0.000939
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 25) -- MSE loss = 0.003046 +/- 0.000934
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 26) -- MSE loss = 0.003007 +/- 0.000932
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 27) -- MSE loss = 0.003292 +/- 0.000965
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 28) -- MSE loss = 0.003029 +/- 0.000927
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 29) -- MSE loss = 0.003004 +/- 0.000924
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch 30) -- MSE loss = 0.003174 +/- 0.000944
# Adjusting learning rate of group 0 to 5.0000e-05.
# Evaluate (epoch
# Adjusting learning rate of group 0 to 2.5000e-05.
# Evaluate (epoch 87) -- MSE loss = 0.002977 +/- 0.000845
# Adjusting learning rate of group 0 to 2.5000e-05.
# Evaluate (epoch 88) -- MSE loss = 0.003036 +/- 0.000859
# Adjusting learning rate of group 0 to 2.5000e-05.
# Evaluate (epoch 89) -- MSE loss = 0.002969 +/- 0.000845
# Adjusting learning rate of group 0 to 2.5000e-05.
# Evaluate (epoch 90) -- MSE loss = 0.002956 +/- 0.000847
# Adjusting learning rate of group 0 to 2.5000e-05.
# Evaluate (epoch 91) -- MSE loss = 0.002976 +/- 0.000839
# Adjusting learning rate of group 0 to 2.5000e-05.
# Evaluate (epoch 92) -- MSE loss = 0.002961 +/- 0.000839
# Adjusting learning rate of group 0 to 2.5000e-05.
# Evaluate (epoch 93) -- MSE loss = 0.002986 +/- 0.000842
# Adjusting learning rate of group 0 to 2.5000e-05.
# Evaluate (epoch 94) -- MSE loss = 0.003055 +/- 0.000843
# Adjusting learning rate of group 0 to 2.5000e-05.
# Evaluate (epoch 95) -- MSE loss = 0.003016 +/- 0.000850
# Adjusting learning rate of group 0 to 2.5000e-05.
# Evaluate (epoch 96) -- MSE loss = 0.002990 +/- 0.000854
# Adjusting learning rate of group 0 to 2.5000e-05.
# Evaluate (epoch 97) -- MSE loss = 0.003073 +/- 0.000844
# Adjusting learning rate of group 0 to 2.5000e-05.
# Evaluate (epoch 98) -- MSE loss = 0.003073 +/- 0.000839
# Adjusting learning rate of group 0 to 2.5000e-05.
# Evaluate (epoch 99) -- MSE loss = 0.002969 +/- 0.000839
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 100) -- MSE loss = 0.002955 +/- 0.000839
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 101) -- MSE loss = 0.002954 +/- 0.000837
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 102) -- MSE loss = 0.002953 +/- 0.000844
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 103) -- MSE loss = 0.002954 +/- 0.000839
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 104) -- MSE loss = 0.002959 +/- 0.000839
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 105) -- MSE loss = 0.002972 +/- 0.000842
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 106) -- MSE loss = 0.002951 +/- 0.000839
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 107) -- MSE loss = 0.002952 +/- 0.000838
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 108) -- MSE loss = 0.002956 +/- 0.000834
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 109) -- MSE loss = 0.002950 +/- 0.000837
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 110) -- MSE loss = 0.002953 +/- 0.000835
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 111) -- MSE loss = 0.002987 +/- 0.000838
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 112) -- MSE loss = 0.002967 +/- 0.000839
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 113) -- MSE loss = 0.002963 +/- 0.000840
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 114) -- MSE loss = 0.002956 +/- 0.000837
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 115) -- MSE loss = 0.002956 +/- 0.000837
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 116) -- MSE loss = 0.002955 +/- 0.000837
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 117) -- MSE loss = 0.002972 +/- 0.000831
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 118) -- MSE loss = 0.002964 +/- 0.000838
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 119) -- MSE loss = 0.002952 +/- 0.000839
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 120) -- MSE loss = 0.002978 +/- 0.000842
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 121) -- MSE loss = 0.002959 +/- 0.000843
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 122) -- MSE loss = 0.002952 +/- 0.000833
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 123) -- MSE loss = 0.002968 +/- 0.000836
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 124) -- MSE loss = 0.002947 +/- 0.000836
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 125) -- MSE loss = 0.002957 +/- 0.000836
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 126) -- MSE loss = 0.002948 +/- 0.000830
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 127) -- MSE loss = 0.002951 +/- 0.000836
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 128) -- MSE loss = 0.002967 +/- 0.000833
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 129) -- MSE loss = 0.002991 +/- 0.000838
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 130) -- MSE loss = 0.003002 +/- 0.000833
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 131) -- MSE loss = 0.002956 +/- 0.000834
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 132) -- MSE loss = 0.002949 +/- 0.000834
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 133) -- MSE loss = 0.002956 +/- 0.000831
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 134) -- MSE loss = 0.002954 +/- 0.000832
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 135) -- MSE loss = 0.002959 +/- 0.000835
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 136) -- MSE loss = 0.002967 +/- 0.000828
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 137) -- MSE loss = 0.002956 +/- 0.000836
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 138) -- MSE loss = 0.002963 +/- 0.000837
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 139) -- MSE loss = 0.002986 +/- 0.000828
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 140) -- MSE loss = 0.002951 +/- 0.000829
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 141) -- MSE loss = 0.002963 +/- 0.000831
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 142) -- MSE loss = 0.002946 +/- 0.000827
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 143) -- MSE loss = 0.002953 +/- 0.000831
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 144) -- MSE loss = 0.002943 +/- 0.000824
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 145) -- MSE loss = 0.002951 +/- 0.000822
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 146) -- MSE loss = 0.002972 +/- 0.000838
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 147) -- MSE loss = 0.002998 +/- 0.000828
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 148) -- MSE loss = 0.002963 +/- 0.000827
# Adjusting learning rate of group 0 to 1.2500e-05.
# Evaluate (epoch 149) -- MSE loss = 0.002950 +/- 0.000833
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 150) -- MSE loss = 0.002972 +/- 0.000834
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 151) -- MSE loss = 0.002961 +/- 0.000832
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 152) -- MSE loss = 0.002945 +/- 0.000823
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 153) -- MSE loss = 0.002952 +/- 0.000828
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 154) -- MSE loss = 0.002947 +/- 0.000830
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 155) -- MSE loss = 0.002952 +/- 0.000829
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 156) -- MSE loss = 0.002946 +/- 0.000824
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 157) -- MSE loss = 0.002943 +/- 0.000824
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 158) -- MSE loss = 0.002949 +/- 0.000831
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 159) -- MSE loss = 0.002948 +/- 0.000825
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 160) -- MSE loss = 0.002946 +/- 0.000827
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 161) -- MSE loss = 0.002949 +/- 0.000829
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 162) -- MSE loss = 0.002973 +/- 0.000825
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 163) -- MSE loss = 0.002944 +/- 0.000829
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 164) -- MSE loss = 0.002944 +/- 0.000825
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 165) -- MSE loss = 0.002941 +/- 0.000823
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 166) -- MSE loss = 0.002960 +/- 0.000831
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 167) -- MSE loss = 0.002943 +/- 0.000827
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 168) -- MSE loss = 0.002944 +/- 0.000828
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 169) -- MSE loss = 0.002949 +/- 0.000823
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 170) -- MSE loss = 0.002943 +/- 0.000826
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 171) -- MSE loss = 0.002943 +/- 0.000827
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 172) -- MSE loss = 0.002944 +/- 0.000824
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 173) -- MSE loss = 0.002942 +/- 0.000826
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 174) -- MSE loss = 0.002948 +/- 0.000824
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 175) -- MSE loss = 0.002958 +/- 0.000821
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 176) -- MSE loss = 0.002952 +/- 0.000823
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 177) -- MSE loss = 0.002945 +/- 0.000826
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 178) -- MSE loss = 0.002948 +/- 0.000825
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 179) -- MSE loss = 0.002943 +/- 0.000826
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 180) -- MSE loss = 0.002957 +/- 0.000820
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 181) -- MSE loss = 0.002942 +/- 0.000820
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 182) -- MSE loss = 0.002946 +/- 0.000827
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 183) -- MSE loss = 0.002940 +/- 0.000823
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 184) -- MSE loss = 0.002955 +/- 0.000820
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 185) -- MSE loss = 0.002944 +/- 0.000819
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 186) -- MSE loss = 0.002947 +/- 0.000827
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 187) -- MSE loss = 0.002952 +/- 0.000820
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 188) -- MSE loss = 0.002957 +/- 0.000827
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 189) -- MSE loss = 0.002944 +/- 0.000823
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 190) -- MSE loss = 0.002941 +/- 0.000819
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 191) -- MSE loss = 0.002941 +/- 0.000823
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 192) -- MSE loss = 0.002944 +/- 0.000824
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 193) -- MSE loss = 0.002943 +/- 0.000823
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 194) -- MSE loss = 0.002942 +/- 0.000819
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 195) -- MSE loss = 0.002951 +/- 0.000822
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 196) -- MSE loss = 0.002976 +/- 0.000834
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 197) -- MSE loss = 0.002941 +/- 0.000818
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 198) -- MSE loss = 0.002942 +/- 0.000822
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 199) -- MSE loss = 0.002941 +/- 0.000821
# Adjusting learning rate of group 0 to 6.2500e-06.
# Evaluate (epoch 200) -- MSE loss = 0.002941 +/- 0.000824
